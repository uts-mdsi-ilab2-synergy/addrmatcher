# %%
import pyarrow.parquet as pq
import glob
from sklearn.neighbors import BallTree
import numpy as np
files = glob.glob('data/*.parquet')
def find_property(lat, lon, km = None , n = 1):
    deg = 110.574 # 1 lat equals 110.574km
    # min and max lat for all properties within Australia
    lat_min = -43.58301104
    lat_max = -9.23000371
    lon_min = 96.82159219
    lon_max = 167.99384663
      
        
    # lat and lon must be within above range
    lat = max(lat, lat_min)
    lat = min(lat, lat_max)
    lon = max(lon, lon_min)
    lon = min(lon, lon_max)
    
    def load_parquet():
        df = pq.\
            read_pandas(
            files, 
            columns=['ADDRESS_DETAIL_PID','LATITUDE', 'LONGITUDE'],
            filters=
            [('LATITUDE', '>=', lat - distance),
             ('LATITUDE', '<=', lat + distance),
             ('LONGITUDE', '>=', lon - distance),
             ('LONGITUDE', '<=', lon + distance)   
            ]).\
            to_pandas()
        return df

    min_distance = 0
    if km == None:
        distance = 1 / deg # start with 10 km
        while True:
            df = load_parquet()
            if df.shape[0] >= n: break
            min_distance = distance
            distance *= 2 
    else:
        distance = abs(km) / deg 
        df = load_parquet()
        if df.empty: return None
    
    while True:
        if df.shape[0] <= n + 10000: break
        middle_distance = (distance-min_distance)/2
        temp_df = df[
            df.LATITUDE.\
            between(
                lat - middle_distance, 
                lat + middle_distance
            ) &
            df.LONGITUDE.\
            between(
                lon - middle_distance, 
                lon + middle_distance
            )]
        if temp_df.shape[0] <= n + 10000: 
            break
        else:
            distance = middle_distance
            df = temp_df  
    bt = BallTree(np.deg2rad(df[['LATITUDE', 'LONGITUDE']].values), metric='haversine')
    distances, indices = bt.query(np.deg2rad(np.c_[lat, lon]), k= min(n, df.shape[0]))
    indices = indices[0].tolist()
    pids = df.ADDRESS_DETAIL_PID.iloc[indices].tolist()
    distance_map = dict(zip(pids ,[distance * 6371 for distance in distances[0]]))
    df =  pq.\
            read_pandas(
            files, 
            filters=
            [[('ADDRESS_DETAIL_PID', '=', pid)] for pid in pids]).\
            to_pandas()
    df['DISTANCE'] = df['ADDRESS_DETAIL_PID'].map(distance_map)
    return df.sort_values('DISTANCE')
#     return df.sort_values('DISTANCE').to_json(orient='records')

# %%
find_property(-33.8965368,151.2066979, n=10)
# Out:
#        ADDRESS_DETAIL_PID DATE_CREATED DATE_LAST_MODIFIED DATE_RETIRED  \
# index
# 648507     GANSW706213980   2008-04-18         2021-05-18         None
# 648501     GANSW706213978   2008-04-18         2021-05-18         None
# 648545     GANSW706213982   2008-04-18         2021-05-18         None
# 648532     GANSW706213976   2008-04-19         2021-05-18         None
# 648506     GANSW706213984   2008-04-18         2021-05-18         None
# 648549     GANSW706213974   2008-04-19         2021-05-18         None
# 648009     GANSW706221291   2007-04-06         2021-05-18         None
# 648019     GANSW710337250   2008-01-05         2021-05-18         None
# 648005     GANSW706221290   2008-04-18         2021-05-18         None
# 648546     GANSW706213986   2008-04-18         2021-05-18         None
#
#        BUILDING_NAME LOT_NUMBER_PREFIX LOT_NUMBER LOT_NUMBER_SUFFIX  \
# index
# 648507          None              None       None              None
# 648501          None              None       None              None
# 648545          None              None       None              None
# 648532          None              None         41              None
# 648506          None              None       None              None
# 648549          None              None         42              None
# 648009          None              None          1              None
# 648019          None              None       None              None
# 648005          None              None       None              None
# 648546          None              None       None              None
#
#        FLAT_TYPE_CODE FLAT_NUMBER_PREFIX  ...  \
# index                                     ...
# 648507           None               None  ...
# 648501           None               None  ...
# 648545           None               None  ...
# 648532           None               None  ...
# 648506           None               None  ...
# 648549           None               None  ...
# 648009           None               None  ...
# 648019           None               None  ...
# 648005           None               None  ...
# 648546           None               None  ...
#
#                                FULL_ADDRESS  \
# index
# 648507    676ELIZABETHSTREETWATERLOONSW2017
# 648501    674ELIZABETHSTREETWATERLOONSW2017
# 648545    678ELIZABETHSTREETWATERLOONSW2017
# 648532  41672ELIZABETHSTREETWATERLOONSW2017
# 648506    680ELIZABETHSTREETWATERLOONSW2017
# 648549  42670ELIZABETHSTREETWATERLOONSW2017
# 648009   1645ELIZABETHSTREETWATERLOONSW2017
# 648019   645AELIZABETHSTREETWATERLOONSW2017
# 648005    643ELIZABETHSTREETWATERLOONSW2017
# 648546    682ELIZABETHSTREETWATERLOONSW2017
#
#                                            CARTESIAN_COOR LGA_NAME_2016  \
# index
# 648507  (-4634.411653893615, 2547.058076540619, -3553....    Sydney (C)
# 648501  (-4634.414212878535, 2547.0588099694655, -3553...    Sydney (C)
# 648545  (-4634.409175534078, 2547.0573663590226, -3553...    Sydney (C)
# 648532  (-4634.416760745312, 2547.0595404466985, -3553...    Sydney (C)
# 648506  (-4634.406770932971, 2547.0566777570384, -3553...    Sydney (C)
# 648549  (-4634.419257180301, 2547.060256347886, -3553....    Sydney (C)
# 648009  (-4634.39102525185, 2547.1034254093565, -3553....    Sydney (C)
# 648019  (-4634.39102525185, 2547.1034254093565, -3553....    Sydney (C)
# 648005  (-4634.393609713892, 2547.104108623732, -3553....    Sydney (C)
# 648546  (-4634.404236248303, 2547.05595030938, -3553.0...    Sydney (C)
#
#          SSC_NAME_2016                  SA4_NAME_2016      SA3_NAME_2016  \
# index
# 648507  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648501  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648545  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648532  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648506  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648549  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648009  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648019  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648005  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
# 648546  Waterloo (NSW)  Sydney - City and Inner South  Sydney Inner City
#
#                   SA2_NAME_2016 SA1_7DIGITCODE_2016 MB_CODE_2016  DISTANCE
# index
# 648507  Waterloo - Beaconsfield             1133837  10755030000  0.023088
# 648501  Waterloo - Beaconsfield             1133837  10755030000  0.023230
# 648545  Waterloo - Beaconsfield             1133837  10755030000  0.023846
# 648532  Waterloo - Beaconsfield             1133837  10755030000  0.024288
# 648506  Waterloo - Beaconsfield             1133837  10755030000  0.025350
# 648549  Waterloo - Beaconsfield             1133837  10755030000  0.026105
# 648009  Waterloo - Beaconsfield             1133840  10753210000  0.027130
# 648019  Waterloo - Beaconsfield             1133840  10753210000  0.027130
# 648005  Waterloo - Beaconsfield             1133840  10753210000  0.027273
# 648546  Waterloo - Beaconsfield             1133837  10755030000  0.027619
#
# [10 rows x 52 columns]

# %%
lat_min = -43.58301104
lat_max = -9.23000371
lon_min = 96.82159219
lon_max = 167.99384663
lat_list = np.random.uniform(lat_min, lat_max, size=100).tolist()
lon_list = np.random.uniform(lon_min, lon_max, size=100).tolist()

# %%
for lat, lon in zip(lat_list, lon_list):

    df = find_property(lat,lon, n=10)
    print(f'Most close address to {lat:.4f},{lon:.4f} is {df.iloc[0].FULL_ADDRESS} in {df.iloc[0].DISTANCE:.2f}km')
# Out:
# Most close address to -28.9312,129.3205 is 23OAKDRIVEOAK VALLEYSA5690 in 147.02km
# Most close address to -10.3812,152.8654 is 73MAROUROADMER ISLANDQLD4875 in 966.09km
# Most close address to -16.4123,142.9496 is 4BURKE DEVELOPMENTALROADHIGHBURYQLD4892 in 6.40km
# Most close address to -35.0298,99.3826 is 1CONTOROADBORANUPWA6286 in 1433.10km
# Most close address to -32.0410,155.5665 is 728SOUTHTERRACEWOOLINSW2462 in 325.76km
# Most close address to -11.3672,148.5304 is 105BMAROUROADMER ISLANDQLD4875 in 515.35km
# Most close address to -27.4146,103.9106 is 3090USELESS LOOPROADCARRARANGWA6532 in 946.52km
# Most close address to -34.3595,145.6071 is 1577CARRATHOOLROADCARRATHOOLNSW2711 in 3.09km
# Most close address to -39.3544,131.7315 is 102RIGHT WHALEROADSLEAFORDSA5607 in 601.65km
# Most close address to -32.7956,144.4159 is 19913COBAR-IVANHOEROADIVANHOENSW2878 in 6.01km
# Most close address to -36.8043,115.1344 is 299MACALLENWAYWINDY HARBOURWA6262 in 233.07km
# Most close address to -23.8606,148.5541 is 6COMET ROLLESTONROADTOGARAQLD4702 in 5.64km
# Most close address to -9.7279,147.3494 is 560LAS VILLAGEMER ISLANDQLD4875 in 361.96km
# Most close address to -34.7996,160.9337 is 178MULLEYDRIVELORD HOWE ISLANDNSW2898 in 400.62km
# Most close address to -31.1375,167.0517 is 46ROCKY POINTROADNORFOLK ISLAND2899 in 246.27km
# Most close address to -22.4303,113.5397 is 166MINILYA-EXMOUTHROADEXMOUTH GULFWA6707 in 43.92km
# Most close address to -26.8746,133.0334 is 4NGIN TAKASTREETIWANTJASA0872 in 28.81km
# Most close address to -17.3115,105.4346 is 11BTONG YAN LOHROADCHRISTMAS ISLAND6798 in 759.33km
# Most close address to -35.6371,133.6348 is 665POINT AVOIDROADCOFFIN BAYSA5607 in 186.04km
# Most close address to -41.2615,151.6862 is 273ST HELENS POINTROADAKAROATAS7216 in 280.40km
# Most close address to -38.6705,117.1564 is 114SHELLEY BEACHROADKRONKUPWA6330 in 401.54km
# Most close address to -38.2507,165.1575 is 178MULLEYDRIVELORD HOWE ISLANDNSW2898 in 928.37km
# Most close address to -28.5832,108.8228 is 3090USELESS LOOPROADCARRARANGWA6532 in 516.42km
# Most close address to -19.4401,139.5522 is 100BURKETOWN QUAMBYROADTHREE RIVERSQLD4824 in 8.12km
# Most close address to -32.6902,109.9125 is 1310TEAKLEROADBOWESWA6535 in 644.47km
# Most close address to -25.1210,105.8527 is 3090USELESS LOOPROADCARRARANGWA6532 in 763.97km
# Most close address to -39.9093,111.6349 is 253ISLANDVIEWWINDY HARBOURWA6262 in 684.34km
# Most close address to -27.8269,163.2313 is 2SKYLINEDRIVELORD HOWE ISLANDNSW2898 in 574.75km
# Most close address to -10.1619,151.2826 is 88MAROUROADMER ISLANDQLD4875 in 792.22km
# Most close address to -19.7516,124.3024 is 10NIYIKINAROADST GEORGE RANGESWA6728 in 138.08km
# Most close address to -21.6091,125.2445 is 8LAKE GREGORYROADSTURT CREEKWA6770 in 296.14km
# Most close address to -36.6466,160.2894 is 178MULLEYDRIVELORD HOWE ISLANDNSW2898 in 577.72km
# Most close address to -30.9447,147.0660 is 2377GONGOLGONROADCOOLABAHNSW2831 in 4.86km
# Most close address to -41.2388,120.7490 is 501SALMON HOLEROADTORNDIRRUPWA6330 in 724.53km
# Most close address to -15.8922,137.8410 is 22604CALVERTROADCALVERTNT0862 in 121.88km
# Most close address to -12.0429,167.2566 is 28ANSON BAYROADNORFOLK ISLAND2899 in 1886.63km
# Most close address to -10.8222,111.2799 is 380GOLF COURSEROADCHRISTMAS ISLAND6798 in 610.92km
# Most close address to -28.9153,140.9487 is 11046RIECKSROADBOLLARDS LAGOONSA5731 in 9.61km
# Most close address to -13.7277,112.0113 is 380GOLF COURSEROADCHRISTMAS ISLAND6798 in 777.45km
# Most close address to -35.9429,156.1326 is 1771EMARINEDRIVEFINGAL BAYNSW2315 in 506.73km
# Most close address to -31.6565,101.1539 is 261INJIDUP SPRINGROADYALLINGUPWA6282 in 1313.64km
# Most close address to -12.2948,127.9017 is 4042MARINDJAROADRAKULANT0822 in 259.61km
# Most close address to -32.0162,154.5236 is 11LIGHTHOUSEROADPORT MACQUARIENSW2444 in 161.86km
# Most close address to -16.4029,151.0165 is 7ISLANDROADCORAL SEAQLD4800 in 484.34km
# Most close address to -39.0587,143.5261 is 1140LIGHTHOUSEROADCAPE OTWAYVIC3233 in 22.81km
# Most close address to -31.4670,165.5233 is 46ROCKY POINTROADNORFOLK ISLAND2899 in 354.13km
# Most close address to -33.8801,135.7845 is 2HUNDRED LINEROADTOOLIGIESA5607 in 2.25km
# Most close address to -11.7225,114.6147 is 380GOLF COURSEROADCHRISTMAS ISLAND6798 in 982.84km
# Most close address to -11.9720,112.0744 is 380GOLF COURSEROADCHRISTMAS ISLAND6798 in 715.61km
# Most close address to -39.5347,105.4006 is 506SKIPPY ROCKROADLEEUWINWA6290 in 1038.05km
# Most close address to -23.7244,145.6831 is 25NARBETHONGROADBARCALDINEQLD4725 in 4.68km
# Most close address to -34.7622,144.6648 is 2940ROMANIROADHAY SOUTHNSW2711 in 6.24km
# Most close address to -24.6684,143.5165 is 16024498JUNDAH LONGREACHROADSTONEHENGEQLD4730 in 10.88km
# Most close address to -38.3420,160.1434 is 178MULLEYDRIVELORD HOWE ISLANDNSW2898 in 761.57km
# Most close address to -23.9041,148.6925 is 1COMET ROLLESTONROADTOGARAQLD4702 in 2.14km
# Most close address to -16.5934,140.0426 is 315LARDILSTREETSOUTH WELLESLEY ISLANDSQLD4892 in 80.11km
# Most close address to -12.2823,98.7187 is 209JALAN KIPASHOME ISLAND6799 in 198.59km
# Most close address to -25.4351,134.1493 is 1BRISCOECRESCENTFINKENT0872 in 45.77km
# Most close address to -35.7214,141.3737 is 298ARTHURSROADBIG DESERTVIC3490 in 20.72km
# Most close address to -32.3716,115.2967 is 152ARCADIADRIVESHOALWATERWA6169 in 38.85km
# Most close address to -14.2148,105.5700 is 1BTONG YAN LOHROADCHRISTMAS ISLAND6798 in 414.74km
# Most close address to -33.4796,130.6521 is 449EYREHIGHWAYNULLARBORSA5690 in 211.28km
# Most close address to -39.6954,147.6213 is 4857PALANAROADPALANATAS7255 in 22.41km
# Most close address to -37.2628,152.3490 is 2086GREEN CAPE LIGHTHOUSEROADGREEN CAPENSW2551 in 203.53km
# Most close address to -26.7866,137.3191 is 591WARBURTONTRACKSIMPSON DESERTSA5734 in 16.52km
# Most close address to -10.7340,116.2291 is 3001BROOME-CAPE LEVEQUEROADDAMPIER PENINSULAWA6725 in 959.16km
# Most close address to -11.0829,156.0292 is 8UNIT620WHITSUNDAYBOULEVARDWHITSUNDAYSQLD4803 in 1276.85km
# Most close address to -28.2192,163.9145 is 429ANSON BAYROADNORFOLK ISLAND2899 in 400.61km
# Most close address to -11.5611,141.5698 is 5ESPLANADEMAPOONQLD4874 in 56.37km
# Most close address to -33.3319,116.4449 is 102NUNDEDINEROADBOWELLINGWA6225 in 3.76km
# Most close address to -22.3500,137.6093 is 35033PLENTYHIGHWAYANATYENT0872 in 8.90km
# Most close address to -19.4493,109.9148 is 198PACERETREATNORTH WEST CAPEWA6707 in 505.22km
# Most close address to -20.2174,107.8898 is 198PACERETREATNORTH WEST CAPEWA6707 in 661.97km
# Most close address to -40.6011,124.8102 is 5WHARTONROADCONDINGUPWA6450 in 767.98km
# Most close address to -30.4564,152.5066 is 213716DARKWOODROADBRINERVILLENSW2454 in 1.96km
# Most close address to -39.2746,134.2554 is 1CAPE DU COUEDICROADFLINDERS CHASESA5223 in 417.60km
# Most close address to -9.9367,121.4176 is 3001BROOME-CAPE LEVEQUEROADDAMPIER PENINSULAWA6725 in 736.46km
# Most close address to -14.0429,138.2283 is 53MAMARIKAROADUMBAKUMBANT0822 in 153.96km
# Most close address to -38.6177,116.5143 is 56RAME HEADROADPEACEFUL BAYWA6333 in 399.34km
# Most close address to -22.1617,144.5992 is 3BOWEN DOWNSROADPRAIRIEQLD4821 in 7.47km
# Most close address to -41.5145,148.3321 is 22394TASMANHIGHWAYFALMOUTHTAS7215 in 4.52km
# Most close address to -35.7960,150.3083 is 3172KAROOCRESCENTMALUA BAYNSW2536 in 6.63km
# Most close address to -28.0131,139.3500 is 102BIRDSVILLETRACKMUNGERANIESA5733 in 27.34km
# Most close address to -34.1069,120.4201 is 2400SPRINGDALEROADJERDACUTTUPWA6346 in 22.78km
# Most close address to -17.0164,98.5252 is 130AIR FORCEROADWEST ISLAND6799 in 564.76km
# Most close address to -28.8085,156.7081 is 611BROWNELLDRIVEBYRON BAYNSW2481 in 300.10km
# Most close address to -15.8578,145.6521 is 86ESPLANADECAPE TRIBULATIONQLD4873 in 28.45km
# Most close address to -25.0938,144.3358 is 19372456EMMET HIGHLANDSROADISISFORDQLD4731 in 3.66km
# Most close address to -13.5679,132.3325 is 5816KAKADUHIGHWAYBURRUNDIENT0822 in 12.90km
# Most close address to -12.0985,130.0121 is 1410CHARLES POINTROADCOX PENINSULANT0822 in 74.04km
# Most close address to -13.2774,130.8926 is 3800DALY RIVERROADLITCHFIELD PARKNT0822 in 11.10km
# Most close address to -41.6749,165.6736 is 178MULLEYDRIVELORD HOWE ISLANDNSW2898 in 1269.62km
# Most close address to -41.5197,127.4061 is 605BARINGROADBOYATUPWA6450 in 933.50km
# Most close address to -11.7656,142.5567 is 3TELEGRAPHROADSHELBURNEQLD4874 in 32.10km
# Most close address to -36.9295,146.4005 is 1660UPPER KING RIVERROADCHESHUNT SOUTHVIC3678 in 2.13km
# Most close address to -30.0437,148.0894 is 11254CASTLEREAGHHIGHWAYWALGETTNSW2832 in 1.77km
# Most close address to -33.8542,116.1635 is 1074GREENBUSHES-BOYUP BROOKROADCATTERICKWA6255 in 0.23km
# Most close address to -41.5787,108.8853 is 506SKIPPY ROCKROADLEEUWINWA6290 in 970.97km
# Most close address to -23.4628,116.2628 is 186NORTH WEST COASTALHIGHWAYNANUTARRAWA6751 in 109.41km
# Most close address to -34.4095,142.9470 is 1989EUSTON PRUNGLEROADEUSTONNSW2737 in 2.92km

# %%
 import timeit
    
# %timeit -n 5 -r 4 find_property(np.random.uniform(lat_min, lat_max),np.random.uniform(lon_min, lon_max), n=50)
# Out:
# 4.84 s ± 1.38 s per loop (mean ± std. dev. of 4 runs, 5 loops each)

# %%
import glob
import os
glob.glob(os.path.join('data', '*.parquet'))
# Out:
# ['data/VIC-GNAF.parquet',
#  'data/NT-GNAF.parquet',
#  'data/ACT-GNAF.parquet',
#  'data/NSW-GNAF.parquet',
#  'data/SA-GNAF.parquet',
#  'data/OT-GNAF.parquet',
#  'data/QLD-GNAF.parquet',
#  'data/WA-GNAF.parquet',
#  'data/TAS-GNAF.parquet']
