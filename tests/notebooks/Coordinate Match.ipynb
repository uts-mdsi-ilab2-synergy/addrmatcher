# %%
import pyarrow.parquet as pq
import glob
import os
from sklearn.neighbors import BallTree
import numpy as np
from pyarrow import fs

local = fs.LocalFileSystem()
files = glob.glob(os.path.join('data1','*.parquet'))

filepath = os.path.join('data1')

def find_property(lat, lon, filepath, km = None , n = 1, ):
    deg = 110.574 # 1 lat equals 110.574km
    # min and max lat for all properties within Australia
    lat_min = -43.58301104
    lat_max = -9.23000371
    lon_min = 96.82159219
    lon_max = 167.99384663
    files = glob.glob(os.path.join(filepath,'*.parquet'))
        
    # lat and lon must be within above range
#     lat = max(lat, lat_min)
#     lat = min(lat, lat_max)
#     lon = max(lon, lon_min)
#     lon = min(lon, lon_max)
    
    def load_parquet():
        df = pq.\
            read_pandas(
            files, 
            columns=['IDX','LATITUDE', 'LONGITUDE', 'FILE_NAME'],
            filesystem=local,
            filters=
            [('LATITUDE', '>=', lat - distance),
             ('LATITUDE', '<=', lat + distance),
             ('LONGITUDE', '>=', lon - distance),
             ('LONGITUDE', '<=', lon + distance)   
            ]).\
            to_pandas()
        return df

    min_distance = 0
    if km == None:
        distance = 10 / deg # start with 10 km
        while True:
            df = load_parquet()
            if df.shape[0] >= n: break
            min_distance = distance
            distance *= 2 ** 0.5
    else:
        distance = abs(km) / deg 
        df = load_parquet()
        if df.empty: return None
    
    while True:
        if df.shape[0] <= n + 10000: break
        middle_distance = (distance-min_distance)/2
        temp_df = df[
            df.LATITUDE.\
            between(
                lat - middle_distance, 
                lat + middle_distance
            ) &
            df.LONGITUDE.\
            between(
                lon - middle_distance, 
                lon + middle_distance
            )]
        if temp_df.shape[0] <= n + 10000: 
            break
        else:
            distance = middle_distance
            df = temp_df  
    bt = BallTree(np.deg2rad(df[['LATITUDE', 'LONGITUDE']].values), metric='haversine')
    distances, indices = bt.query(np.deg2rad(np.c_[lat, lon]), k= min(n, df.shape[0]))
    indices = indices[0].tolist()
    pids = df.IDX.iloc[indices].tolist()
    distance_map = dict(zip(pids ,[distance * 6371 for distance in distances[0]]))
    files = [os.path.join(filepath, filename) for filename in df.FILE_NAME.unique().tolist()]
    
    df =  pq.\
          read_pandas(
            files, 
            filesystem=local,
            filters=
            [[('IDX', '=', pid)] for pid in pids]).\
            to_pandas()
    df['DISTANCE'] = df['IDX'].map(distance_map)
    return df.sort_values('DISTANCE')
#     return df.sort_values('DISTANCE').to_json(orient='records')

# %%
find_property(-30.4379424, 137.916172, filepath, n=10)[['FULL_ADDRESS', 'LATITUDE', 'LONGITUDE', 'DISTANCE']]
# Out:
#                                            FULL_ADDRESS   LATITUDE  \
# index
# 126682  1682 MYRTLE SPRINGS ROAD MYRTLE SPRINGS SA 5731 -30.450277
# 126681   388 MYRTLE SPRINGS ROAD MYRTLE SPRINGS SA 5731 -30.452686
# 126645                  19 SOUTH TERRACE FARINA SA 5731 -30.077352
# 126644                   1 SOUTH TERRACE FARINA SA 5731 -30.077349
# 126643                  21 SOUTH TERRACE FARINA SA 5731 -30.077351
# 126642                  45 SOUTH TERRACE FARINA SA 5731 -30.077350
# 126641                 133 SOUTH TERRACE FARINA SA 5731 -30.077350
# 126640                   2 SOUTH TERRACE FARINA SA 5731 -30.077351
# 126638                 160 SOUTH TERRACE FARINA SA 5731 -30.075504
# 126637                  12 SOUTH TERRACE FARINA SA 5731 -30.077350
# 126636                  17 SOUTH TERRACE FARINA SA 5731 -30.077352
# 126635                  10 SOUTH TERRACE FARINA SA 5731 -30.077029
# 126634                   8 SOUTH TERRACE FARINA SA 5731 -30.077030
# 126646                  18 SOUTH TERRACE FARINA SA 5731 -30.077352
# 126639                  13 SOUTH TERRACE FARINA SA 5731 -30.077351
# 452896                  49 EIGHTH STREET FARINA SA 5731 -30.076503
# 452897                  29 EIGHTH STREET FARINA SA 5731 -30.077029
# 452879                  60 EIGHTH STREET FARINA SA 5731 -30.076499
# 452893                  41 EIGHTH STREET FARINA SA 5731 -30.077029
# 452892                  52 EIGHTH STREET FARINA SA 5731 -30.076503
# 452891                  27 EIGHTH STREET FARINA SA 5731 -30.077029
# 452890                  65 EIGHTH STREET FARINA SA 5731 -30.076338
# 452889                 422 EIGHTH STREET FARINA SA 5731 -30.073053
# 452888                   2 EIGHTH STREET FARINA SA 5731 -30.077031
# 452887                  25 EIGHTH STREET FARINA SA 5731 -30.077027
# 452886                 106 EIGHTH STREET FARINA SA 5731 -30.075669
# 452885                  71 EIGHTH STREET FARINA SA 5731 -30.076496
# 452884                  63 EIGHTH STREET FARINA SA 5731 -30.076340
# 452883                 128 EIGHTH STREET FARINA SA 5731 -30.075509
# 452882                  45 EIGHTH STREET FARINA SA 5731 -30.077031
# 452881                  28 EIGHTH STREET FARINA SA 5731 -30.077029
# 452880                 109 EIGHTH STREET FARINA SA 5731 -30.076339
# 452894                 111 EIGHTH STREET FARINA SA 5731 -30.076503
# 452895                  34 EIGHTH STREET FARINA SA 5731 -30.076497
#
#          LONGITUDE   DISTANCE
# index
# 126682  138.217683  28.936483
# 126681  138.325823  28.936483
# 126645  138.279470  52.888333
# 126644  138.274681  52.888333
# 126643  138.280235  52.888333
# 126642  138.275258  52.888333
# 126641  138.280810  52.888333
# 126640  138.273909  52.888333
# 126638  138.273761  52.888333
# 126637  138.276979  52.888333
# 126636  138.278895  52.888333
# 126635  138.276693  52.888333
# 126634  138.274680  52.888333
# 126646  138.279179  52.888333
# 126639  138.277457  52.888333
# 452896  138.274677  52.933318
# 452897  138.279756  52.933318
# 452879  138.277594  52.933318
# 452893  138.275544  52.933318
# 452892  138.274196  52.933318
# 452891  138.280522  52.933318
# 452890  138.279029  52.933318
# 452889  138.276098  52.933318
# 452888  138.273336  52.933318
# 452887  138.280955  52.933318
# 452886  138.276543  52.933318
# 452885  138.280948  52.933318
# 452884  138.278168  52.933318
# 452883  138.278883  52.933318
# 452882  138.274199  52.933318
# 452881  138.280235  52.933318
# 452880  138.279752  52.933318
# 452894  138.276402  52.933318
# 452895  138.280376  52.933318

# %%
lat_min = -43.58301104
lat_max = -9.23000371
lon_min = 96.82159219
lon_max = 167.99384663
lat_list = np.random.uniform(lat_min, lat_max, size=100).tolist()
lon_list = np.random.uniform(lon_min, lon_max, size=100).tolist()

# %%
pq.read_pandas(files[0]).schema
# Out:
# index: int64
# IDX: int32
# FULL_ADDRESS: string
# LATITUDE: double
# LONGITUDE: double
# LGA_NAME_2016: string
# SSC_NAME_2016: string
# SA4_NAME_2016: string
# SA3_NAME_2016: string
# SA2_NAME_2016: string
# SA1_7DIGITCODE_2016: string
# MB_CODE_2016: string
# STREET_NAME: string
# STREET_TYPE_CODE: string
# LOCALITY_NAME: string
# STATE: string
# POSTCODE: string
# ADDRESS_DETAIL_PID: string
# FILE_NAME: string
# -- schema metadata --
# pandas: '{"column_indexes": [{"field_name": null, "metadata": null, "name' + 2540

# %%
for lat, lon in zip(lat_list, lon_list):

    df = find_property(lat,lon, filepath, n=10)
    print(f'Most close address to {lat:.4f},{lon:.4f} is {df.iloc[0].FULL_ADDRESS} in {df.iloc[0].DISTANCE:.2f}km')
# Out:
# Most close address to -9.5695,154.1721 is 97 BRAMSTON BEACH ROAD BRAMSTON BEACH QLD 4871 in 1234.44km
# Most close address to -20.3126,97.5867 is 130 AIR FORCE ROAD WEST ISLAND 6799 in 905.02km
# Most close address to -30.1784,135.6596 is 20031 BILLA KALINA ROAD MOUNT EBA SA 5720 in 0.75km
# Most close address to -33.0397,119.5515 is 4 NEWDEGATE-RAVENSTHORPE ROAD LAKE KING WA 6356 in 5.59km
# Most close address to -11.4221,166.9911 is 3 LADY ELLIOT ISLAND CORAL SEA QLD 4800 in 2065.15km
# Most close address to -14.4016,148.3882 is 44 BACK BEACH ROAD YARRABAH QLD 4871 in 383.00km
# Most close address to -40.5879,119.3027 is 501 SALMON HOLE ROAD TORNDIRRUP WA 6330 in 621.30km
# Most close address to -41.6550,154.3305 is 1 AIRPORT ROAD MALLACOOTA VIC 3892 in 599.41km
# Most close address to -40.0170,114.7730 is 348 TINGLEWOOD ROAD BROKE WA 6398 in 582.27km
# Most close address to -31.6933,123.6530 is 43 EYRE HIGHWAY FRASER RANGE WA 6443 in 74.00km
# Most close address to -42.3717,144.2510 is 5 CANNONBALL DRIVE GRANVILLE HARBOUR TAS 7469 in 89.80km
# Most close address to -22.2784,97.0249 is 130 AIR FORCE ROAD WEST ISLAND 6799 in 1120.30km
# Most close address to -15.7851,164.4083 is 34 3 ORCHID COURT FRASER ISLAND QLD 4581 in 1540.67km
# Most close address to -11.3257,158.1916 is MM 1 GRASSTREE PLACE WHITSUNDAYS QLD 4803 in 1406.30km
# Most close address to -14.9934,123.0576 is 88 CYGNET BAY ROAD DAMPIER PENINSULA WA 6725 in 162.94km
# Most close address to -26.1599,100.8527 is 3090 USELESS LOOP ROAD CARRARANG WA 6532 in 1248.13km
# Most close address to -34.7269,154.8712 is 2 UNIT 2 68 MARINE DRIVE FINGAL BAY NSW 2315 in 331.07km
# Most close address to -37.9193,129.0367 is 9564 MERIVALE ROAD CAPE ARID WA 6452 in 704.59km
# Most close address to -17.5570,146.3408 is 1 INARLINGA ROAD COWLEY BEACH QLD 4871 in 22.74km
# Most close address to -22.3474,137.7029 is 9 URANDANGI ROAD PITURIE QLD 4825 in 102.10km
# Most close address to -23.2562,122.4039 is 187 KARIMARRA STREET JIGALONG WA 6753 in 165.63km
# Most close address to -36.8732,103.1286 is 7 TURTLEDOVE RISE GREENOUGH WA 6532 in 1393.16km
# Most close address to -12.5266,125.3018 is 124 KALUMBURU BOULEVARD KALUMBURU WA 6740 in 243.67km
# Most close address to -27.5923,162.8416 is 2 SKYLINE DRIVE LORD HOWE ISLAND NSW 2898 in 569.14km
# Most close address to -9.3446,120.8092 is 3001 BROOME-CAPE LEVEQUE ROAD DAMPIER PENINSULA WA 6725 in 817.65km
# Most close address to -39.4755,148.6518 is 963 NORTH EAST RIVER ROAD PALANA TAS 7255 in 67.08km
# Most close address to -42.0926,147.4325 is 500 TUNBRIDGE TIER ROAD TUNBRIDGE TAS 7120 in 3.79km
# Most close address to -25.2414,137.8115 is 1 13 EYRE DEVELOPMENTAL ROAD BIRDSVILLE QLD 4482 in 121.42km
# Most close address to -28.7792,135.8262 is 1522 OODNADATTA TRACK NILPINNA STATION SA 5723 in 18.39km
# Most close address to -29.6976,125.5812 is 1 TRANS ACCESS ROAD RAWLINNA WA 6434 in 161.23km
# Most close address to -30.0240,120.8680 is 185 DAVYHURST-ORA BANDA ROAD ORA BANDA WA 6431 in 31.85km
# Most close address to -22.7139,151.5557 is 124 STANAGE BAY ROAD SHOALWATER QLD 4702 in 74.45km
# Most close address to -17.2735,115.0701 is 615 BURRUP ROAD BURRUP WA 6714 in 411.47km
# Most close address to -36.8616,116.5806 is 23 STATION ROAD NORNALUP WA 6333 in 204.79km
# Most close address to -34.5881,126.3686 is 100 EYRE HIGHWAY COCKLEBIDDY WA 6443 in 284.69km
# Most close address to -23.9689,112.4614 is 937 GNARALOO ROAD MACLEOD WA 6701 in 106.90km
# Most close address to -41.8822,113.5052 is 348 TINGLEWOOD ROAD BROKE WA 6398 in 813.08km
# Most close address to -15.1750,116.7586 is 196 BURRUP ROAD BURRUP WA 6714 in 602.37km
# Most close address to -42.1846,101.8955 is 506 SKIPPY ROCK ROAD LEEUWIN WA 6290 in 1443.82km
# Most close address to -16.0039,163.4947 is 3 LADY ELLIOT ISLAND CORAL SEA QLD 4800 in 1441.69km
# Most close address to -14.9755,136.9770 is 2150 BATTEN ROAD MCARTHUR NT 0852 in 115.01km
# Most close address to -17.9237,156.7668 is 2 AIRSTRIP ROAD CURTIS ISLAND QLD 4680 in 855.06km
# Most close address to -13.3486,164.9918 is 2 LADY ELLIOT ISLAND CORAL SEA QLD 4800 in 1760.14km
# Most close address to -39.3014,132.7513 is 20 WEST END HIGHWAY FLINDERS CHASE SA 5223 in 507.97km
# Most close address to -25.2251,136.1531 is 1495 MOUNT DARE ROAD WITJIRA SA 5734 in 133.33km
# Most close address to -19.5769,132.8577 is 8601 STUART HIGHWAY WARUMUNGU NT 0852 in 89.79km
# Most close address to -41.8230,111.9676 is 217 WINDY HARBOUR ROAD WINDY HARBOUR WA 6262 in 853.40km
# Most close address to -34.6192,149.5182 is 5 1927 POMEROY ROAD BANNISTER NSW 2580 in 1.37km
# Most close address to -31.9362,111.8528 is 1868 WEDGE ISLAND ROAD WEDGE ISLAND WA 6044 in 341.60km
# Most close address to -33.9251,146.4722 is 18 236 ANDERSONS LANE WEETHALLE NSW 2669 in 4.42km
# Most close address to -37.0303,119.6154 is 501 SALMON HOLE ROAD TORNDIRRUP WA 6330 in 260.98km
# Most close address to -26.7603,125.7591 is 13 SECOND STREET TJIRRKARLI WA 0872 in 96.81km
# Most close address to -20.0516,139.0296 is 3 1344 THORNTONIA YELVERTOFT ROAD GUNPOWDER QLD 4825 in 27.04km
# Most close address to -38.2597,142.8009 is 479 COYLES ROAD GARVOC VIC 3265 in 1.23km
# Most close address to -34.1343,159.4539 is 178 MULLEY DRIVE LORD HOWE ISLAND NSW 2898 in 289.63km
# Most close address to -15.3483,107.0846 is 1 B TONG YAN LOH ROAD CHRISTMAS ISLAND 6798 in 563.04km
# Most close address to -23.3506,144.8902 is 67 LANDSBOROUGH HIGHWAY BARCALDINE QLD 4725 in 7.92km
# Most close address to -18.3273,152.4636 is 71 KESWICK ISLAND DRIVE CORAL SEA QLD 4800 in 429.84km
# Most close address to -28.1284,157.4713 is 11 32 BROWNELL DRIVE BYRON BAY NSW 2481 in 379.37km
# Most close address to -36.6402,156.3466 is 12 7 CROOKHAVEN PARADE CURRARONG NSW 2540 in 529.01km
# Most close address to -34.5269,150.8437 is 25 22 KOTARI PARADE LAKE ILLAWARRA NSW 2528 in 1.72km
# Most close address to -10.9873,151.4293 is 206 UNIT 206 119 121 WILLIAMS ESPLANADE PALM COVE QLD 4879 in 891.70km
# Most close address to -30.5967,136.1632 is 7561 BILLA KALINA ROAD PARAKYLIA SA 5720 in 32.52km
# Most close address to -39.7833,158.5492 is 1 SCERRI DRIVE KIOLOA NSW 2539 in 858.20km
# Most close address to -26.9039,154.3921 is 47 MORETON ISLAND MORETON ISLAND QLD 4025 in 99.65km
# Most close address to -35.0526,136.2419 is 45 WHALERS DRIVE THISTLE ISLAND SA 5606 in 7.03km
# Most close address to -26.3228,124.6158 is 13 SECOND STREET TJIRRKARLI WA 0872 in 84.32km
# Most close address to -20.5737,141.3913 is 1 FLINDERS HIGHWAY JULIA CREEK QLD 4823 in 7.24km
# Most close address to -33.1072,117.8234 is 2874 WISHBONE ROAD NORTH MOULYINNING WA 6351 in 2.55km
# Most close address to -25.5676,106.3676 is 3090 USELESS LOOP ROAD CARRARANG WA 6532 in 704.60km
# Most close address to -17.3217,138.9084 is 19 ATHERTON STREET NICHOLSON QLD 4830 in 33.53km
# Most close address to -33.6001,121.3764 is 30 COOMALBIDGUP ROAD LORT RIVER WA 6447 in 5.31km
# Most close address to -23.3785,163.5222 is 47 FISHERMANS LANE NORFOLK ISLAND 2899 in 763.77km
# Most close address to -13.3309,115.0006 is 565 MOF ROAD BURRUP WA 6714 in 830.56km
# Most close address to -11.1077,111.5162 is 31 PHOSPHATE HILL ROAD CHRISTMAS ISLAND 6798 in 641.09km
# Most close address to -34.8136,117.7548 is 588 OLD COACH ROAD NARRIKUP WA 6326 in 1.06km
# Most close address to -35.3488,137.6796 is 675 CLAN RANALD ROAD HONITON SA 5576 in 20.70km
# Most close address to -36.5376,146.3723 is 143 FURLANS LANE DOCKER VIC 3678 in 0.64km
# Most close address to -23.8670,140.4239 is 550 10185 GRIFFITHS TANK COORABULKA ROAD BEDOURIE QLD 4829 in 40.46km
# Most close address to -24.1914,115.6294 is 64 ULLAWARRA ROAD GASCOYNE RIVER WA 6705 in 88.46km
# Most close address to -33.8877,130.6136 is 22 WANDILLA BEACH ROAD COORABIE SA 5690 in 258.85km
# Most close address to -27.7349,165.0229 is 162 ANSON BAY ROAD NORFOLK ISLAND 2899 in 316.84km
# Most close address to -31.8142,142.0994 is 71 MENINDEE ROAD BROKEN HILL NSW 2880 in 17.70km
# Most close address to -41.8761,147.3172 is 1034 MACQUARIE ROAD CAMPBELL TOWN TAS 7210 in 2.48km
# Most close address to -28.1090,161.6002 is 2 SKYLINE DRIVE LORD HOWE ISLAND NSW 2898 in 451.21km
# Most close address to -14.1370,139.9347 is 208 208 MANCHKUNCHAN STREET PORMPURAAW QLD 4892 in 199.88km
# Most close address to -28.5215,120.3390 is 176 OLD AGNEW ROAD LEINSTER WA 6437 in 46.87km
# Most close address to -37.5164,124.0538 is 513 ALEXANDER ROAD HOWICK WA 6450 in 420.17km
# Most close address to -42.9383,163.3772 is 178 MULLEY DRIVE LORD HOWE ISLAND NSW 2898 in 1321.91km
# Most close address to -41.7152,134.5332 is 419 D CAPE DU COUEDIC ROAD FLINDERS CHASE SA 5223 in 656.48km
# Most close address to -25.3010,155.8917 is 20 FRASER ISLAND FRASER ISLAND QLD 4581 in 257.20km
# Most close address to -22.7673,100.8855 is 130 AIR FORCE ROAD WEST ISLAND 6799 in 1250.00km
# Most close address to -17.3585,125.6059 is 143 LEOPOLD DOWNS ROAD KING LEOPOLD RANGES WA 6728 in 69.97km
# Most close address to -15.0690,161.9375 is 3 LADY ELLIOT ISLAND CORAL SEA QLD 4800 in 1393.86km
# Most close address to -23.5886,98.5128 is 130 AIR FORCE ROAD WEST ISLAND 6799 in 1278.03km
# Most close address to -14.9382,109.1238 is 11 TAMAN SWEETLANDS CRESCENT CHRISTMAS ISLAND 6798 in 623.05km
# Most close address to -11.8916,135.2404 is 395 GANAPAY PARADE GALIWINKU NT 0822 in 38.06km
# Most close address to -18.6143,151.6523 is 1 MELALEUCA DRIVE WHITSUNDAYS QLD 4803 in 341.58km
# Most close address to -21.1088,155.6319 is 3 LADY ELLIOT ISLAND CORAL SEA QLD 4800 in 448.92km
# Most close address to -37.7542,167.7293 is 14 QUALITY ROW NORFOLK ISLAND 2899 in 967.13km

# %%
 import timeit
    
# %timeit find_property(np.random.uniform(lat_min, lat_max),np.random.uniform(lon_min, lon_max), filepath, n=50)
# Out:
# The slowest run took 35.70 times longer than the fastest. This could mean that an intermediate result is being cached.
# 664 ms ± 1.04 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def find_no_property(lat, lon, filepath, km = 10):
    deg = 110.574 # 1 lat equals 110.574km
    distance = abs(km) / deg 
    # min and max lat for all properties within Australia
    files = glob.glob(os.path.join(filepath,'*.parquet'))
        
    rowcount = pq.\
        read_pandas(
        files, 
        columns=['LATITUDE', 'LONGITUDE'],
        filesystem=local,
        filters=
        [('LATITUDE', '>=', lat - distance),
         ('LATITUDE', '<=', lat + distance),
         ('LONGITUDE', '>=', lon - distance),
         ('LONGITUDE', '<=', lon + distance)   
        ]).num_rows
    return rowcount

# %%
find_no_property(-33.8688, 151.2093, filepath, km = 2)
# Out:
# 138817
